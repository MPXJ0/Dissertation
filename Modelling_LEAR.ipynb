# %%
t1=pd.read_csv('NP.csv')
t2=pd.read_csv('final datasets/imbalanceData.csv')
t3=pd.read_csv('final datasets/auctionData.csv')

# %%
t2.loc[t2['HAsolar'] == 0,'HAsolar'] = t2['HAsolar'].apply(lambda x: round(np.random.random(),2))
t2.loc[t2['solarForecast'] == 0,'solarForecast'] = t2['solarForecast'].apply(lambda x: round(np.random.random(),2))
t3.loc[t3['solarForecast'] == 0,'solarForecast'] = t3['solarForecast'].apply(lambda x: round(np.random.random(),2))

# %%
t2.to_csv('imbalanceData_final.csv',index=False)
t3.to_csv('auctionData_final.csv',index=False)

# %% [markdown]
# ### testing period
# 2020/07/20 - 07/26
# 2020/10/19 - 10/25
# 2021/01/18 - 01/24
# 2021/04/19 - 04/25

# %% [markdown]
# ### calibration window
# 2 weeks, 14 days
# 4 weeks, 28 days
# 26 weeks, 182 days
# 52 weeks, 364 days

# %%
import pandas as pd
import numpy as np
from epftoolbox.models import evaluate_lear_in_test_dataset

# %%
df1 = pd.read_csv('final datasets/imbalanceData_final.csv')
df2 = pd.read_csv('final datasets/auctionData_final.csv')

# %%
df1[['datetime','imbalancePrice','loadForecast','demandForecast','aggrForecast',
     'solarForecast','windOffForecast','windOnForecast']].to_csv('final datasets/imb_fore_6.csv',index=False)

# %%
df3 = pd.read_csv('final datasets/imb_fore_6.csv')

# %%
df1[['datetime','imbalancePrice','loadForecast','demandForecast','aggrForecast']].to_csv('final datasets/imb_sysfore_3.csv',index=False)

# %%
df1[['datetime','imbalancePrice','solarForecast','windOffForecast','windOnForecast']].to_csv('final datasets/imb_swfore_3.csv',index=False)

# %%
df1[['datetime','imbalancePrice','HAimbalanceVolume','HAload','HAdemand',
     'HAsolar','HAwindOff','HAwindOn']].to_csv('final datasets/imb_HA_6.csv',index=False)

# %%
df1[['datetime','imbalancePrice','HAimbalanceVolume','HAload','HAdemand']].to_csv('final datasets/imb_sysHA_3.csv',index=False)

# %%
df1[['datetime','imbalancePrice','HAsolar','HAwindOff','HAwindOn']].to_csv('final datasets/imb_swHA_3.csv',index=False)

# %%
df1[['datetime','imbalancePrice','HAimbalanceVolume','HAload','HAdemand',
     'loadForecast','demandForecast','aggrForecast']].to_csv('final datasets/imb_sys_6.csv',index=False)

# %%
df1[['datetime','imbalancePrice','HAsolar','HAwindOff','HAwindOn',
     'solarForecast','windOffForecast','windOnForecast']].to_csv('final datasets/imb_sw_6.csv',index=False)

# %%
df2 = pd.read_csv('final datasets/auctionData_final.csv')

# %%
df2.head()
# Out:
#               datetime  auctionPrice  loadForecast  demandForecast  \
# 0  2018-11-02 01:00:00         52.24         53851           56856
# 1  2018-11-02 02:00:00         50.71         52461           56815
# 2  2018-11-02 03:00:00         50.56         51589           56089
# 3  2018-11-02 04:00:00         49.52         52108           55422
# 4  2018-11-02 05:00:00         49.96         56408           56967
#
#    aggrForecast  solarForecast  windOffForecast  windOnForecast
# 0         56845           0.76             5772            7868
# 1         55892           0.95             5694            8110
# 2         54787           0.14             5514            8128
# 3         54548           0.85             5344            7848
# 4         56399          17.00             5032            7368

# %%
cols=['loadForecast','demandForecast','aggrForecast','solarForecast','windOffForecast','windOnForecast']
df2[cols]=df2[cols]/2
df2.head()
# Out:
#               datetime  auctionPrice  loadForecast  demandForecast  \
# 0  2018-11-02 01:00:00         52.24       26925.5         28428.0
# 1  2018-11-02 02:00:00         50.71       26230.5         28407.5
# 2  2018-11-02 03:00:00         50.56       25794.5         28044.5
# 3  2018-11-02 04:00:00         49.52       26054.0         27711.0
# 4  2018-11-02 05:00:00         49.96       28204.0         28483.5
#
#    aggrForecast  solarForecast  windOffForecast  windOnForecast
# 0       28422.5          0.380           2886.0          3934.0
# 1       27946.0          0.475           2847.0          4055.0
# 2       27393.5          0.070           2757.0          4064.0
# 3       27274.0          0.425           2672.0          3924.0
# 4       28199.5          8.500           2516.0          3684.0

# %%
decimals = pd.Series([0,0,0,2,0,0], index=['loadForecast','demandForecast','aggrForecast',
                                           'solarForecast','windOffForecast','windOnForecast'])
df_rounded = df2.round(decimals)

# %%
cols = ['loadForecast','demandForecast','aggrForecast','windOffForecast','windOnForecast']
df_rounded[cols] = df_rounded[cols].applymap(np.int64)

# %%
df_rounded.to_csv('auctionData.csv',index=False)

# %%
df_rounded[['datetime','auctionPrice','loadForecast','demandForecast','aggrForecast']].to_csv('auc_sysfore_3.csv',index=False)
df_rounded[['datetime','auctionPrice','solarForecast','windOffForecast','windOnForecast']].to_csv('auc_swfore_3.csv',index=False)

# %%
df2[['datetime','auctionPrice','loadForecast','demandForecast','aggrForecast']].to_csv('final datasets/auc_sysfore_3.csv',index=False)
df2[['datetime','auctionPrice','solarForecast','windOffForecast','windOnForecast']].to_csv('final datasets/auc_swfore_3.csv',index=False)

# %%
# df1
['datetime','imbalancePrice']
['HAimbalanceVolume','HAload','HAdemand','HAsolar','HAwindOff','HAwindOn']
['loadForecast','demandForecast','aggrForecast','solarForecast','windOffForecast','windOnForecast']

# df2
['datetime','auctionPrice']
['loadForecast','demandForecast','aggrForecast','solarForecast','windOffForecast','windOnForecast']

# %% [markdown]
# # July 2020

# %%
# data to study
dataset = 'imb_sw_6'

# 1 year is considered as 364 days (52 weeks)
# years_test = 1

# Number of days used in the training dataset for recalibration
calibration_window = 364

# Optional parameters for selecting the test dataset
begin_test_date = '2020-07-20'
end_test_date = '2020-07-26'
    
evaluate_lear_in_test_dataset(path_datasets_folder = 'final datasets',
                              path_recalibration_folder = 'forecast results',
                              dataset = dataset,
                              #years_test = years_test,
                              calibration_window = calibration_window,
                              begin_test_date = begin_test_date,
                              end_test_date = end_test_date)
# Out:
# Test datasets: 2020-07-20 00:00:00 - 2020-07-26 23:00:00
# 2020-07-20 - sMAPE: 60.96%  |  MAE: 16.467
# 2020-07-21 - sMAPE: 53.43%  |  MAE: 15.131
# 2020-07-22 - sMAPE: 51.77%  |  MAE: 14.082
# 2020-07-23 - sMAPE: 50.92%  |  MAE: 13.711
# 2020-07-24 - sMAPE: 52.03%  |  MAE: 14.240
# 2020-07-25 - sMAPE: 52.15%  |  MAE: 14.231
# 2020-07-26 - sMAPE: 51.02%  |  MAE: 14.114
#                    h0         h1         h2         h3         h4         h5  \
# datetime
# 2020-07-20
6'

# 1 year is considered as 364 days (52 weeks)
# years_test = 1

# Number of days used in the training dataset for recalibration
calibration_window = 364

# Optional parameters for selecting the test dataset
begin_test_date = '2020-10-19'
end_test_date = '2020-10-25'
    
evaluate_lear_in_test_dataset(path_datasets_folder = 'final datasets',
                              path_recalibration_folder = 'forecast results',
                              dataset = dataset,
                              #years_test = years_test,
                              calibration_window = calibration_window,
                              begin_test_date = begin_test_date,
                              end_test_date = end_test_date)
# Out:
# Test datasets: 2020-10-19 00:00:00 - 2020-10-25 23:00:00
# 2020-10-19 - sMAPE: 52.72%  |  MAE: 19.758
# 2020-10-20 - sMAPE: 42.98%  |  MAE: 16.254
# 2020-10-21 - sMAPE: 47.61%  |  MAE: 18.948
# 2020-10-22 - sMAPE: 48.58%  |  MAE: 19.693
# 2020-10-23 - sMAPE: 48.44%  |  MAE: 20.026
# 2020-10-24 - sMAPE: 49.25%  |  MAE: 19.598
# 2020-10-25 - sMAPE: 54.98%  |  MAE: 21.287
#                    h0         h1         h2         h3         h4         h5  \
# datetime
# 2020-10-19  34.465517  40.959845   5.131459  48.790923  44.244632  49.237468
# 2020-10-20   23.37504  20.333389  27.063525  36.286858   6.483756  29.981796
# 2020-10-21  53.413853  70.885059  82.638089  51.179647  67.053964  61.994654
# 2020-10-22  25.592451  24.942875  36.627849   4.513608  12.907259   23.63056
# 2020-10-23  38.798689  48.081669  58.334166  58.087787  43.226806  32.125853
# 2020-10-24  33.224024  45.449281   39.09305  50.664253  28.692186  16.960124
# ...

# %%
# data to study
dataset = 'imbalanceData_final'

# 1 year is considered as 364 days (52 weeks)
# years_test = 1

# Number of days used in the training dataset for recalibration
calibration_window = 364

# Optional parameters for selecting the test dataset
begin_test_date = '2020-10-19'
end_test_date = '2020-10-25'
    
evaluate_lear_in_test_dataset(path_datasets_folder = 'final datasets',
                              path_recalibration_folder = 'forecast results',
                              dataset = dataset,
                              #years_test = years_test,
                              calibration_window = calibration_window,
                              begin_test_date = begin_test_date,
                              end_test_date = end_test_date)
# Out:
# Test datasets: 2020-10-19 00:00:00 - 2020-10-25 23:00:00
# 2020-10-19 - sMAPE: 29.37%  |  MAE: 9.689
# 2020-10-20 - sMAPE: 25.74%  |  MAE: 9.355
# 2020-10-21 - sMAPE: 28.85%  |  MAE: 9.899
# 2020-10-22 - sMAPE: 32.67%  |  MAE: 10.568
# 2020-10-23 - sMAPE: 31.52%  |  MAE: 10.966
# 2020-10-24 - sMAPE: 34.12%  |  MAE: 11.604
# 2020-10-25 - sMAPE: 41.21%  |  MAE: 13.052
#                    h0         h1         h2         h3         h4         h5  \
# datetime
# 2020-10-19  38.420572  53.461806  40.589265  65.066425  59.008877  36.166127
# 2020-10-20  28.241514  37.375425  42.134532  43.217033  35.558579  23.210679
# 2020-10-21   9.439448  21.018885  33.489185  32.503586  22.268696   9.265456
# 2020-10-22  25.473632  41.650403  34.168689  -5.862619  -2.001461  31.888297
# 2020-10-23  49.563183  56.373399  49.618493   51.07108  45.758791  40.587523
# 2020-10-24   24.34696    8.78233  23.830086  15.547275  15.314813  16.101447
# ...

# %% [markdown]
# # January 2021

# %%
# data to study
dataset = 'imb_sys_6'

# 1 year is considered as 364 days (52 weeks)
# years_test = 1

# Number of days used in the training dataset for recalibration
calibration_window = 364

# Optional parameters for selecting the test dataset
begin_test_date = '2021-01-18'
end_test_date = '2021-01-24'
    
evaluate_lear_in_test_dataset(path_datasets_folder = 'final datasets',
                              path_recalibration_folder = 'forecast results',
                              dataset = dataset,
                              #years_test = years_test,
                              calibration_window = calibration_window,
                              begin_test_date = begin_test_date,
                              end_test_date = end_test_date)

# %%
# data to study
dataset = 'imb_sw_6'

# 1 year is considered as 364 days (52 weeks)
# years_test = 1

# Number of days used in the training dataset for recalibration
calibration_window = 364

# Optional parameters for selecting the test dataset
begin_test_date = '2021-01-18'
end_test_date = '2021-01-24'
    
evaluate_lear_in_test_dataset(path_datasets_folder = 'final datasets',
                              path_recalibration_folder = 'forecast results',
                              dataset = dataset,
                              #years_test = years_test,
                              calibration_window = calibration_window,
                              begin_test_date = begin_test_date,
                              end_test_date = end_test_date)

# %%
imb_fore_6

# %%
imb_HA_6

# %%
imb_sysfore_3

# %%
imb_sysHA_3

# %%
imb_swfore_3

# %%
imb_swHA_3

# %%
imbalanceData_final

# %% [markdown]
# # April 2021
